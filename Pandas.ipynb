# %%
import pandas as pd
import numpy as np
data=np.array([11,22,43,45,85,96,77])
s=pd.Series(data)
s
# Out:
# 0    11
# 1    22
# 2    43
# 3    45
# 4    85
# 5    96
# 6    77
# dtype: int32

# %%
s[3]
# Out:
# 45

# %%
#help(s)

# %%
import pandas as pd
import numpy as np
data=np.array([11,22,43,45,85,96,77])
s=pd.Series(data, index=["A","B","C","D","E","F","G"])
s
# Out:
# A    11
# B    22
# C    43
# D    45
# E    85
# F    96
# G    77
# dtype: int32

# %%
import pandas as pd
import numpy as np
ind=np.arange(100,107)
data=np.array([11,22,43,45,85,96,77])
s=pd.Series(data, index=ind)
s
# Out:
# 100    11
# 101    22
# 102    43
# 103    45
# 104    85
# 105    96
# 106    77
# dtype: int32

# %%
s.shape
# Out:
# (7,)

# %%
s.ndim
# Out:
# 1

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
len(s)
# Out:
# 7

# %%
import pandas as pd
import numpy as np
data=np.arange(100,200,5).reshape(5,4)
df=pd.DataFrame(data, columns=["First","Second", "Third","Fourth" ])
df
# Out:
#    First  Second  Third  Fourth
# 0    100     105    110     115
# 1    120     125    130     135
# 2    140     145    150     155
# 3    160     165    170     175
# 4    180     185    190     195

# %%
#help(df)

# %%
df.shape
# Out:
# (5, 2)

# %%
df.ndim
# Out:
# 2

# %%
len(df)
# Out:
# 5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.First
# Out:
# 0    100
# 1    120
# 2    140
# 3    160
# 4    180
# Name: First, dtype: int32

# %%
type(df.First)
# Out:
# pandas.core.series.Series

# %%
df['First']
# Out:
# 0    100
# 1    120
# 2    140
# 3    160
# 4    180
# Name: First, dtype: int32

# %%
df[["First", "Third"]]
# Out:
#    First  Third
# 0    100    110
# 1    120    130
# 2    140    150
# 3    160    170
# 4    180    190

# %%
df.loc[0]
# Out:
# First     100
# Second    105
# Third     110
# Fourth    115
# Name: 0, dtype: int32

# %%
df.loc[3,"Second"]
# Out:
# 165

# %%
df.loc[3,["Second", "Third"]]
# Out:
# Second    165
# Third     170
# Name: 3, dtype: int32

# %%
df.loc[[3,4],["Second", "Third"]]
# Out:
#    Second  Third
# 3     165    170
# 4     185    190

# %%
# Dictionary Method
weather_data={
    "Day":["10/02/21","11/02/21","12/02/21","13/02/21","14/02/21","15/02/21","16/02/21","17/02/21","18/02/21"],
    "Temp":[21,22,32,22,24,25,28,27,29],
    "Windspeed":[6,5,8,7,4,5,6,7,8],
    "Event":["Play", "NoPlay","NoPlay","Play","NoPlay","Play","Play","NoPlay","Play"]
}
df=pd.DataFrame(weather_data)
df
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay
# 2  12/02/21    32          8  NoPlay
# 3  13/02/21    22          7    Play
# 4  14/02/21    24          4  NoPlay
# 5  15/02/21    25          5    Play
# 6  16/02/21    28          6    Play
# 7  17/02/21    27          7  NoPlay
# 8  18/02/21    29          8    Play

# %%
df.head()
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay
# 2  12/02/21    32          8  NoPlay
# 3  13/02/21    22          7    Play
# 4  14/02/21    24          4  NoPlay

# %%
df.head(2)
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay

# %%
df.head(8)
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay
# 2  12/02/21    32          8  NoPlay
# 3  13/02/21    22          7    Play
# 4  14/02/21    24          4  NoPlay
# 5  15/02/21    25          5    Play
# 6  16/02/21    28          6    Play
# 7  17/02/21    27          7  NoPlay

# %%
df.tail()
# Out:
#         Day  Temp  Windspeed   Event
# 4  14/02/21    24          4  NoPlay
# 5  15/02/21    25          5    Play
# 6  16/02/21    28          6    Play
# 7  17/02/21    27          7  NoPlay
# 8  18/02/21    29          8    Play

# %%
df.tail(2)
# Out:
#         Day  Temp  Windspeed   Event
# 7  17/02/21    27          7  NoPlay
# 8  18/02/21    29          8    Play

# %%
df.Day
# Out:
# 0    10/02/21
# 1    11/02/21
# 2    12/02/21
# 3    13/02/21
# 4    14/02/21
# 5    15/02/21
# 6    16/02/21
# 7    17/02/21
# 8    18/02/21
# Name: Day, dtype: object

# %%
df[["Temp","Event"]]
# Out:
#    Temp   Event
# 0    21    Play
# 1    22  NoPlay
# 2    32  NoPlay
# 3    22    Play
# 4    24  NoPlay
# 5    25    Play
# 6    28    Play
# 7    27  NoPlay
# 8    29    Play

# %%
df.set_index("Day")
# Out:
#           Temp  Windspeed   Event
# Day
# 10/02/21    21          6    Play
# 11/02/21    22          5  NoPlay
# 12/02/21    32          8  NoPlay
# 13/02/21    22          7    Play
# 14/02/21    24          4  NoPlay
# 15/02/21    25          5    Play
# 16/02/21    28          6    Play
# 17/02/21    27          7  NoPlay
# 18/02/21    29          8    Play

# %%
df
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay
# 2  12/02/21    32          8  NoPlay
# 3  13/02/21    22          7    Play
# 4  14/02/21    24          4  NoPlay
# 5  15/02/21    25          5    Play
# 6  16/02/21    28          6    Play
# 7  17/02/21    27          7  NoPlay
# 8  18/02/21    29          8    Play

# %%
df.set_index("Day", inplace=True)

# %%
df
# Out:
#           Temp  Windspeed   Event
# Day
# 10/02/21    21          6    Play
# 11/02/21    22          5  NoPlay
# 12/02/21    32          8  NoPlay
# 13/02/21    22          7    Play
# 14/02/21    24          4  NoPlay
# 15/02/21    25          5    Play
# 16/02/21    28          6    Play
# 17/02/21    27          7  NoPlay
# 18/02/21    29          8    Play

# %%
df.loc["16/02/21"]
# Out:
# Temp           28
# Windspeed       6
# Event        Play
# Name: 16/02/21, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         Day  Temp  Windspeed   Event
# 0  10/02/21    21          6    Play
# 1  11/02/21    22          5  NoPlay
# 2  12/02/21    32          8  NoPlay
# 3  13/02/21    22          7    Play
# 4  14/02/21    24          4  NoPlay
# 5  15/02/21    25          5    Play
# 6  16/02/21    28          6    Play
# 7  17/02/21    27          7  NoPlay
# 8  18/02/21    29          8    Play

# %%
df.set_index("Day", inplace=True)

# %%
df
# Out:
#           Temp  Windspeed   Event
# Day
# 10/02/21    21          6    Play
# 11/02/21    22          5  NoPlay
# 12/02/21    32          8  NoPlay
# 13/02/21    22          7    Play
# 14/02/21    24          4  NoPlay
# 15/02/21    25          5    Play
# 16/02/21    28          6    Play
# 17/02/21    27          7  NoPlay
# 18/02/21    29          8    Play

# %%
df.iloc[5]
# Out:
# Temp           25
# Windspeed       5
# Event        Play
# Name: 15/02/21, dtype: object

# %%
df.Temp.max()
# Out:
# 32

# %%
df[df["Temp"]>25]
# Out:
#           Temp  Windspeed   Event
# Day
# 12/02/21    32          8  NoPlay
# 16/02/21    28          6    Play
# 17/02/21    27          7  NoPlay
# 18/02/21    29          8    Play

# %%
df[df["Event"]=="Play"]
# Out:
#           Temp  Windspeed Event
# Day
# 10/02/21    21          6  Play
# 13/02/21    22          7  Play
# 15/02/21    25          5  Play
# 16/02/21    28          6  Play
# 18/02/21    29          8  Play

# %%
df.describe()
# Out:
#             Temp  Windspeed
# count   9.000000   9.000000
# mean   25.555556   6.222222
# std     3.711843   1.394433
# min    21.000000   4.000000
# 25%    22.000000   5.000000
# 50%    25.000000   6.000000
# 75%    28.000000   7.000000
# max    32.000000   8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 10/02/21 to 18/02/21
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Temp       9 non-null      int64
#  1   Windspeed  9 non-null      int64
#  2   Event      9 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("mtcars.csv")

# %% [markdown]
# "C:\\Users\\Jay\\Desktop\\4e06d2575eb9589dbe8c365d61cb056c-898a40b035f7c951579041aecbfb2149331fa9f6\\4e06d2575eb9589dbe8c365d61cb056c-898a40b035f7c951579041aecbfb2149331fa9f6\\mtcars.csv"

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#help(df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df=df.rename(columns={'Unnamed: 0':"Car_Model"})

# %%
df
# Out:
#               Car_Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
 a=df[df["mpg"]>20]

# %%
a
# Out:
#          Car_Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# ...

# %%
 df[(df["mpg"]>20) and (df["Mazda RX4 Wag"])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5cc507e984aa> in <module>
# ----> 1 df[(df["mpg"]>20)and (df["Mazda RX4 Wag"])]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df["mpg"]>21) & (df["Car_Model"]=="Datsun 710")]
# Out:
#     Car_Model   mpg  cyl   disp  hp  drat    wt   qsec  vs  am  gear  carb
# 2  Datsun 710  22.8    4  108.0  93  3.85  2.32  18.61   1   1     4     1

# %%
import pandas as pd
import numpy as np
titanic=pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic[["Name","Sex"]]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic[titanic["Age"]<17]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
titanic[titanic["Pclass"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic["Pclass"].isin([2,3])]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[(titanic["Pclass"]==2)|(titanic["Pclass"]==3)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[titanic["Age"].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic["Age"].isna()].shape
# Out:
# (177, 12)

# %%
titanic.loc[titanic["Age"] > 35, ["Name","Pclass","Age"]]
# Out:
#                                                   Name  Pclass   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 6                              McCarthy, Mr. Timothy J       1  54.0
# 11                            Bonnell, Miss. Elizabeth       1  58.0
# 13                         Andersson, Mr. Anders Johan       3  39.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)        2  55.0
# ..                                                 ...     ...   ...
# 865                           Bystrom, Mrs. (Karolina)       2  42.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1  47.0
# 873                        Vander Cruyssen, Mr. Victor       3  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1  56.0
# 885               Rice, Mrs. William (Margaret Norton)       3  39.0
#
# [217 rows x 3 columns]

# %%
# rows 10 till 25 and columns 3 to 5
titanic.iloc[9:25,2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
titanic.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
titanic.iloc[0:3,3]="anonymous"

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic.iloc[0:3,3]=="anonymous"
# Out:
# 0    True
# 1    True
# 2    True
# Name: Name, dtype: bool
